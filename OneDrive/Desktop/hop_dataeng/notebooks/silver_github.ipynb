# %%
# Silver Layer - Github Repositories
# Process:
# 1. Import Libraries needed
# 2. Connect Bronze to Silver
# 3. For Validations
# - Remove Duplicate Repositories
# - Remove rows with null names
# - Standardize date formats
# 4. Transformations
# - Clean languages names
# - Remove special characters from descriptions
# - Convert dates to standard format
# 5. Quality flags
# - Mark repositories with missing languages
# - Mark repositories with missing description

# %%
import os
import json
import pandas as pd
from datetime import datetime
import pyarrow

# %%
BRONZE_FOLDER = "C:/Users/rjaya/OneDrive/Desktop/hop_dataeng/data/bronze"
SILVER_FOLDER = "C:/Users/rjaya/OneDrive/Desktop/hop_dataeng/data/silver"
COLLECTION_DATE = datetime.now().strftime("%Y-%m-%d")

# %%
bronze_json_files = sorted([filename for filename in os.listdir(BRONZE_FOLDER) if filename.endswith('.json')])
load_bronze_file_path = f"{BRONZE_FOLDER}/{bronze_json_files[-1]}"

# %%
with open(load_bronze_file_path) as file:
    data = json.load(file)

print(type(data))
print(len(data))
print(data[0])

flatten_repos = []

for i, item in enumerate(flatten_repos):
    if isinstance(item, str):
        print(f"Index {i}: {item}")

print(len(flatten_repos))
print(sum(1 for item in flatten_repos if isinstance(item, dict)))
print(sum(1 for item in flatten_repos if isinstance(item, str)))
# Out:
# <class 'list'>
# 51
# [{'id': 940929652, 'node_id': 'R_kgDOOBVydA', 'name': '1590A', 'full_name': 'torvalds/1590A', 'private': False, 'owner': {'login': 'torvalds', 'id': 1024025, 'node_id': 'MDQ6VXNlcjEwMjQwMjU=', 'avatar_url': 'https://avatars.githubusercontent.com/u/1024025?v=4', 'gravatar_id': '', 'url': 'https://api.github.com/users/torvalds', 'html_url': 'https://github.com/torvalds', 'followers_url': 'https://api.github.com/users/torvalds/followers', 'following_url': 'https://api.github.com/users/torvalds/following{/other_user}', 'gists_url': 'https://api.github.com/users/torvalds/gists{/gist_id}', 'starred_url': 'https://api.github.com/users/torvalds/starred{/owner}{/repo}', 'subscriptions_url': 'https://api.github.com/users/torvalds/subscriptions', 'organizations_url': 'https://api.github.com/users/torvalds/orgs', 'repos_url': 'https://api.github.com/users/torvalds/repos', 'events_url': 'https://api.github.com/users/torvalds/events{/privacy}', 'received_events_url': 'https://api.github.com/users/torvalds/received_events', 'type': 'User', 'user_view_type': 'public', 'site_admin': False}, 'html_url': 'https://github.com/torvalds/1590A', 'description': 'Random odd guitar pedal design in kicad', 'fork': False, 'url': 'https://api.github.com/repos/torvalds/1590A', 'forks_url': 'https://api.github.com/repos/torvalds/1590A/forks', 'keys_url': 'https://api.github.com/repos/torvalds/1590A/keys{/key_id}', 'collaborators_url': 'https://api.github.com/repos/torvalds/1590A/collaborators{/collaborator}', 'teams_url': 'https://api.github.com/repos/torvalds/1590A/teams', 'hooks_url': 'https://api.github.com/repos/torvalds/1590A/hooks', 'issue_events_url': 'https://api.github.com/repos/torvalds/1590A/issues/events{/number}', 'events_url': 'https://api.github.com/repos/torvalds/1590A/events', 'assignees_url': 'https://api.github.com/repos/torvalds/1590A/assignees{/user}', 'branches_url': 'https://api.github.com/repos/torvalds/1590A/branches{/branch}', 'tags_url': 'https://api.github.com/repos/torvalds/1590A/tags', 'blobs_url': 'https://api.github.com/repos/torvalds/1590A/git/blobs{/sha}', 'git_tags_url': 'https://api.github.com/repos/torvalds/1590A/git/tags{/sha}', 'git_refs_url': 'https://api.github.com/repos/torvalds/1590A/git/refs{/sha}', 'trees_url': 'https://api.github.com/repos/torvalds/1590A/git/trees{/sha}', 'statuses_url': 'https://api.github.com/repos/torvalds/1590A/statuses/{sha}', 'languages_url': 'https://api.github.com/repos/torvalds/1590A/languages', 'stargazers_url': 'https://api.github.com/repos/torvalds/1590A/stargazers', 'contributors_url': 'https://api.github.com/repos/torvalds/1590A/contributors', 'subscribers_url': 'https://api.github.com/repos/torvalds/1590A/subscribers', 'subscription_url': 'https://api.github.com/repos/torvalds/1590A/subscription', 'commits_url': 'https://api.github.com/repos/torvalds/1590A/commits{/sha}', 'git_commits_url': 'https://api.github.com/repos/torvalds/1590A/git/commits{/sha}', 'comments_url': 'https://api.github.com/repos/torvalds/1590A/comments{/number}', 'issue_comment_url': 'https://api.github.com/repos/torvalds/1590A/issues/comments{/number}', 'contents_url': 'https://api.github.com/repos/torvalds/1590A/contents/{+path}', 'compare_url': 'https://api.github.com/repos/torvalds/1590A/compare/{base}...{head}', 'merges_url': 'https://api.github.com/repos/torvalds/1590A/merges', 'archive_url': 'https://api.github.com/repos/torvalds/1590A/{archive_format}{/ref}', 'downloads_url': 'https://api.github.com/repos/torvalds/1590A/downloads', 'issues_url': 'https://api.github.com/repos/torvalds/1590A/issues{/number}', 'pulls_url': 'https://api.github.com/repos/torvalds/1590A/pulls{/number}', 'milestones_url': 'https://api.github.com/repos/torvalds/1590A/milestones{/number}', 'notifications_url': 'https://api.github.com/repos/torvalds/1590A/notifications{?since,all,participating}', 'labels_url': 'https://api.github.com/repos/torvalds/1590A/labels{/name}', 'releases_url': 'https://api.github.com/repos/torvalds/1590A ...
# 0
# 0
# 0

# %%
flatten_repos = []
for user_repos in data:
    for repo in user_repos:
        flatten_repos.append(repo)


print(type(flatten_repos))
print(flatten_repos[0])
# Out:
# <class 'list'>
# {'id': 940929652, 'node_id': 'R_kgDOOBVydA', 'name': '1590A', 'full_name': 'torvalds/1590A', 'private': False, 'owner': {'login': 'torvalds', 'id': 1024025, 'node_id': 'MDQ6VXNlcjEwMjQwMjU=', 'avatar_url': 'https://avatars.githubusercontent.com/u/1024025?v=4', 'gravatar_id': '', 'url': 'https://api.github.com/users/torvalds', 'html_url': 'https://github.com/torvalds', 'followers_url': 'https://api.github.com/users/torvalds/followers', 'following_url': 'https://api.github.com/users/torvalds/following{/other_user}', 'gists_url': 'https://api.github.com/users/torvalds/gists{/gist_id}', 'starred_url': 'https://api.github.com/users/torvalds/starred{/owner}{/repo}', 'subscriptions_url': 'https://api.github.com/users/torvalds/subscriptions', 'organizations_url': 'https://api.github.com/users/torvalds/orgs', 'repos_url': 'https://api.github.com/users/torvalds/repos', 'events_url': 'https://api.github.com/users/torvalds/events{/privacy}', 'received_events_url': 'https://api.github.com/users/torvalds/received_events', 'type': 'User', 'user_view_type': 'public', 'site_admin': False}, 'html_url': 'https://github.com/torvalds/1590A', 'description': 'Random odd guitar pedal design in kicad', 'fork': False, 'url': 'https://api.github.com/repos/torvalds/1590A', 'forks_url': 'https://api.github.com/repos/torvalds/1590A/forks', 'keys_url': 'https://api.github.com/repos/torvalds/1590A/keys{/key_id}', 'collaborators_url': 'https://api.github.com/repos/torvalds/1590A/collaborators{/collaborator}', 'teams_url': 'https://api.github.com/repos/torvalds/1590A/teams', 'hooks_url': 'https://api.github.com/repos/torvalds/1590A/hooks', 'issue_events_url': 'https://api.github.com/repos/torvalds/1590A/issues/events{/number}', 'events_url': 'https://api.github.com/repos/torvalds/1590A/events', 'assignees_url': 'https://api.github.com/repos/torvalds/1590A/assignees{/user}', 'branches_url': 'https://api.github.com/repos/torvalds/1590A/branches{/branch}', 'tags_url': 'https://api.github.com/repos/torvalds/1590A/tags', 'blobs_url': 'https://api.github.com/repos/torvalds/1590A/git/blobs{/sha}', 'git_tags_url': 'https://api.github.com/repos/torvalds/1590A/git/tags{/sha}', 'git_refs_url': 'https://api.github.com/repos/torvalds/1590A/git/refs{/sha}', 'trees_url': 'https://api.github.com/repos/torvalds/1590A/git/trees{/sha}', 'statuses_url': 'https://api.github.com/repos/torvalds/1590A/statuses/{sha}', 'languages_url': 'https://api.github.com/repos/torvalds/1590A/languages', 'stargazers_url': 'https://api.github.com/repos/torvalds/1590A/stargazers', 'contributors_url': 'https://api.github.com/repos/torvalds/1590A/contributors', 'subscribers_url': 'https://api.github.com/repos/torvalds/1590A/subscribers', 'subscription_url': 'https://api.github.com/repos/torvalds/1590A/subscription', 'commits_url': 'https://api.github.com/repos/torvalds/1590A/commits{/sha}', 'git_commits_url': 'https://api.github.com/repos/torvalds/1590A/git/commits{/sha}', 'comments_url': 'https://api.github.com/repos/torvalds/1590A/comments{/number}', 'issue_comment_url': 'https://api.github.com/repos/torvalds/1590A/issues/comments{/number}', 'contents_url': 'https://api.github.com/repos/torvalds/1590A/contents/{+path}', 'compare_url': 'https://api.github.com/repos/torvalds/1590A/compare/{base}...{head}', 'merges_url': 'https://api.github.com/repos/torvalds/1590A/merges', 'archive_url': 'https://api.github.com/repos/torvalds/1590A/{archive_format}{/ref}', 'downloads_url': 'https://api.github.com/repos/torvalds/1590A/downloads', 'issues_url': 'https://api.github.com/repos/torvalds/1590A/issues{/number}', 'pulls_url': 'https://api.github.com/repos/torvalds/1590A/pulls{/number}', 'milestones_url': 'https://api.github.com/repos/torvalds/1590A/milestones{/number}', 'notifications_url': 'https://api.github.com/repos/torvalds/1590A/notifications{?since,all,participating}', 'labels_url': 'https://api.github.com/repos/torvalds/1590A/labels{/name}', 'releases_url': 'https://api.github.com/repos/torvalds/1590A/ ...

# %%
clean_repos = [repo for repo in flatten_repos if isinstance(repo, dict) and 'name' in repo]
df = pd.DataFrame(clean_repos)

df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1270 entries, 0 to 1269
# Data columns (total 79 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   id                           1270 non-null   int64
#  1   node_id                      1270 non-null   object
#  2   name                         1270 non-null   object
#  3   full_name                    1270 non-null   object
#  4   private                      1270 non-null   bool
#  5   owner                        1270 non-null   object
#  6   html_url                     1270 non-null   object
#  7   description                  1120 non-null   object
#  8   fork                         1270 non-null   bool
#  9   url                          1270 non-null   object
#  10  forks_url                    1270 non-null   object
#  11  keys_url                     1270 non-null   object
#  12  collaborators_url            1270 non-null   object
#  13  teams_url                    1270 non-null   object
#  14  hooks_url                    1270 non-null   object
#  15  issue_events_url             1270 non-null   object
#  16  events_url                   1270 non-null   object
#  17  assignees_url                1270 non-null   object
#  18  branches_url                 1270 non-null   object
#  19  tags_url                     1270 non-null   object
#  20  blobs_url                    1270 non-null   object
#  21  git_tags_url                 1270 non-null   object
#  22  git_refs_url                 1270 non-null   object
#  23  trees_url                    1270 non-null   object
#  24  statuses_url                 1270 non-null   object
#  25  languages_url                1270 non-null   object
#  26  stargazers_url               1270 non-null   object
#  27  contributors_url             1270 non-null   object
#  28  subscribers_url              1270 non-null   object
#  29  subscription_url             1270 non-null   object
#  30  commits_url                  1270 non-null   object
#  31  git_commits_url              1270 non-null   object
#  32  comments_url                 1270 non-null   object
#  33  issue_comment_url            1270 non-null   object
#  34  contents_url                 1270 non-null   object
#  35  compare_url                  1270 non-null   object
#  36  merges_url                   1270 non-null   object
#  37  archive_url                  1270 non-null   object
#  38  downloads_url                1270 non-null   object
#  39  issues_url                   1270 non-null   object
#  40  pulls_url                    1270 non-null   object
#  41  milestones_url               1270 non-null   object
#  42  notifications_url            1270 non-null   object
#  43  labels_url                   1270 non-null   object
#  44  releases_url                 1270 non-null   object
#  45  deployments_url              1270 non-null   object
#  46  created_at                   1270 non-null   object
#  47  updated_at                   1270 non-null   object
#  48  pushed_at                    1269 non-null   object
#  49  git_url                      1270 non-null   object
#  50  ssh_url                      1270 non-null   object
#  51  clone_url                    1270 non-null   object
#  52  svn_url                      1270 non-null   object
#  53  homepage                     804 non-null    object
#  54  size                         1270 non-null   int64
#  55  stargazers_count             1270 non-null   int64
#  56  watchers_count               1270 non-null   int64
#  57  language                     939 non-null    object
#  58  has_issues                   1270 non-null   bool
#  59  has_projects                 1270 non-null   bool
#  60  has_downloads                1270 non-null   bool
#  61  has_wiki                     1270 non-null   bool
#  62  has_pages                    1270 non-null   bool
#  63  has_discussions              1270 non-null   bool
#  64  forks_count                  1270 non-null   int64
#  65  mirror_url                   0 non-null      object
#  66  archived                     1270 non-null   bool
#  67  disabled                     1270 non-null   bool
#  68  open_issues_count            1270 non-null   int64
#  69  license                      691 non-null    object
#  70  allow_forking                1270 non-null   bool
#  71  is_template                  1270 non-null   bool
#  72  web_commit_signoff_required  1270 non-null   bool
#  73  topics                       1270 non-null   object
#  74  visibility                   1270 non-null   object
#  75  forks                        1270 non-null   int64
#  76  open_issues                  1270 non-null   int64
#  77  watchers                     1270 non-null   int64
#  78  default_branch               1270 non-null   object
# dtypes: bool(13), int64(9), object(57)
# memory usage: 671.1+ KB

# %%
df['owner_login'] = df['owner'].apply(lambda x: x['login'] if isinstance(x, dict) else None)
df_github_repos = df[['owner_login', 'name', 'description', 'language', 'stargazers_count', 'created_at', 'updated_at']].copy()

print("Shape:", df_github_repos.shape)
print("\nFirst few rows:")
print(df_github_repos.head())
print(df_github_repos.dtypes)
# Out:
# Shape: (1270, 7)
#
# First few rows:
#   owner_login            name  \
# 0    torvalds           1590A
# 1    torvalds     GuitarPedal
# 2    torvalds  libdc-for-dirk
# 3    torvalds         libgit2
# 4    torvalds           linux
#
#                                          description  language  \
# 0            Random odd guitar pedal design in kicad  OpenSCAD
# 1                       Linus learns analog circuits  OpenSCAD
# 2  Only use for syncing with Dirk, don't use for ...         C
# 3  A cross-platform, linkable library implementat...         C
# 4                           Linux kernel source tree         C
#
#    stargazers_count            created_at            updated_at
# 0               437  2025-03-01T04:36:29Z  2025-11-07T15:08:41Z
# 1              1167  2025-09-17T01:01:29Z  2025-11-14T21:52:13Z
# 2               283  2017-01-17T00:25:49Z  2025-11-05T13:25:16Z
# 3               233  2022-07-30T03:30:56Z  2025-11-14T05:55:17Z
# 4            207061  2011-09-04T22:48:12Z  2025-11-15T00:04:33Z
# owner_login         object
# name                object
# description         object
# language            object
# stargazers_count     int64
# created_at          object
# updated_at          object
# dtype: object

# %%
# Explorations
# Are there duplicate IDs?
duplicate_names = df_github_repos['name'].duplicated().sum()
print("Duplicate Names:", duplicate_names)

# Are there duplicate owner+name combinations?
duplicate_by_owner_name = df_github_repos[['owner_login', 'name']].duplicated().sum()
print("Duplicate owner+name:", duplicate_by_owner_name)

# Show me the actual duplicates
dup_mask = df_github_repos.duplicated(subset=['owner_login', 'name'], keep=False)
print(df_github_repos[dup_mask].sort_values(['owner_login', 'name']))

# Check the null values across all columns
print("Null values in each column:")
print(df_github_repos.isna().sum())
# Out:
# Duplicate Names: 43
# Duplicate owner+name: 0
# Empty DataFrame
# Columns: [owner_login, name, description, language, stargazers_count, created_at, updated_at]
# Index: []
# Null values in each column:
# owner_login           0
# name                  0
# description         150
# language            331
# stargazers_count      0
# created_at            0
# updated_at            0
# dtype: int64

# %%
# Explorations
# Check the null values across all columns
print("Null values in each column:")
print(df_github_repos.isna().sum())

# Check for null names
null_names = df_github_repos['description'].isna().sum()
print(f"Null names: {null_names}")

# Show any null names rows
print(df_github_repos[df_github_repos['description'].isna()])

# Get complete daily quality report
print("Data Quality Report:")
print(df_github_repos.info())
# Out:
# Null values in each column:
# owner_login           0
# name                  0
# description         150
# language            331
# stargazers_count      0
# created_at            0
# updated_at            0
# dtype: int64
# Null names: 150
#      owner_login                                          name description  \
# 10     yyx990803                                    angular.js        None
# 15     yyx990803  babel-plugin-transform-es2015-classes-simple        None
# 17     yyx990803                         babel-preset-flow-vue        None
# 26     yyx990803                         bundle-size-benchmark        None
# 27     yyx990803                            bundle-vs-unbundle        None
# ...          ...                                           ...         ...
# 1250  shanselman                          aspneteverywheredemo        None
# 1256  shanselman                                    azure-docs        None
# 1257  shanselman                                  azure-friday        None
# 1258  shanselman                         azure-mobile-services        None
# 1266  shanselman                              babysmashwebsite        None
#
#                      language  stargazers_count            created_at  \
# 10                 JavaScript                 9  2013-08-15T19:03:09Z
# 15                 JavaScript                 8  2016-05-08T04:10:22Z
# 17                 JavaScript                19  2016-05-12T17:45:31Z
# 26                 JavaScript                 7  2024-12-19T02:29:49Z
# 27                 JavaScript                19  2024-12-25T09:43:33Z
# ...                       ...               ...                   ...
# 1250                      CSS                 7  2016-03-15T21:36:02Z
# 1256  GCC Machine Description                 1  2017-01-13T23:53:34Z
# 1257                    Bicep                27  2021-02-11T19:06:55Z
# 1258                       C#                 1  2013-11-12T17:25:37Z
# 1266                     HTML                 3  2020-10-18T08:27:00Z
#
#                 updated_at
# 10    2025-11-10T12:47:13Z
# 15    2025-11-10T12:47:15Z
# 17    2025-11-10T12:47:15Z
# 26    2025-10-08T11:00:09Z
# 27    2025-10-08T10:59:56Z
# ...                    ...
# 1250  2022-03-27T22:40:19Z
# 1256  2022-03-27T22:40:06Z
# 1257  2025-08-29T20:54:15Z
# 1258  2022-03-27T22:41:23Z
# 1266  2023-10-26T00:10:05Z
#
# [150 rows x 7 columns]
# Data Quality Report:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1270 entries, 0 to 1269
# Data columns (total 7 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   owner_login       1270 non-null   object
#  1   name              1270 non-null   object
#  2   description       1120 non-null   object
#  3   language          939 non-null    object
#  4   stargazers_count  1270 non-null   int64
#  5   created_at        1270 non-null   object
#  6   updated_at        1270 non-null   object
# dtypes: int64(1), object(6)
# memory usage: 69.6+ KB
# None

# %% [markdown]
# #
# #
# #
# #
# #
# ##

# %%
df_github_repos[df_github_repos['language'] == 'Unknown'].shape[0]
print(df_github_repos[['language']])
# Out:
#         language
# 0       OpenSCAD
# 1       OpenSCAD
# 2              C
# 3              C
# 4              C
# ...          ...
# 1265          C#
# 1266        HTML
# 1267          C#
# 1268  JavaScript
# 1269        None
#
# [1270 rows x 1 columns]

# %%
df_github_repos['language'] = df_github_repos['language'].fillna('Unknown')
print(df_github_repos['language'].count())

df_github_repos['description'] = df_github_repos['description'].fillna('No description provided')
print(df_github_repos['description'].count())

print((df_github_repos['language'] == 'Unknown').sum())
print((df_github_repos['description'] == 'No description provided').sum())
# Out:
# 1270
# 1270
# 331
# 150

# %%
df_github_repos['created_at'] = pd.to_datetime(df_github_repos['created_at'])
df_github_repos['updated_at'] = pd.to_datetime(df_github_repos['updated_at'])

print(df_github_repos.dtypes)
print("\nFirst few rows after conversion:")
print(df_github_repos[["created_at", "updated_at"]].head())
# Out:
# owner_login                      object
# name                             object
# description                      object
# language                         object
# stargazers_count                  int64
# created_at          datetime64[ns, UTC]
# updated_at          datetime64[ns, UTC]
# dtype: object
#
# First few rows after conversion:
#                  created_at                updated_at
# 0 2025-03-01 04:36:29+00:00 2025-11-07 15:08:41+00:00
# 1 2025-09-17 01:01:29+00:00 2025-11-14 21:52:13+00:00
# 2 2017-01-17 00:25:49+00:00 2025-11-05 13:25:16+00:00
# 3 2022-07-30 03:30:56+00:00 2025-11-14 05:55:17+00:00
# 4 2011-09-04 22:48:12+00:00 2025-11-15 00:04:33+00:00

# %%
# Create a Silver File Path to save Parquet Files
silver_file_path = f"{SILVER_FOLDER}/{COLLECTION_DATE}_github_users.parquet"

df_github_repos.to_parquet(silver_file_path)
print(f"Data saved to:", silver_file_path)
# Out:
# Data saved to: C:/Users/rjaya/OneDrive/Desktop/hop_dataeng/data/silver/2025-11-19_github_users.parquet
